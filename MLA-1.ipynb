# %% [markdown]
# #
#
#
# nowadays we are dealing woth great amount of data
#
# big data
# 3vs
# variety in data arriving from heterogeneous application
# volume (tera bytes of data)
# velocity (at which speed the data is arriving)
#
#
# how a machine will learn?
#  algorithms
#
# 1. Supervised -classification(outputis discrete)
#                 regression (output is continuous)
#
# 2. Unsupervised -we don  not have any historical info unlike supervised learning
#
# 3. Reinforcement -
#
#
#
#
# Steps to solve a machine learning Problem
#
# data gatering
#
# data preprocessing
#
# feature engineering - making data useful
#
# algorithm traingn & selection
#
# predictions - evaluating the model
